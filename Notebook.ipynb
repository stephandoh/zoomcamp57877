# %%
# !pip install pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (2.0.43)
# Requirement already satisfied: psycopg2-binary in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (2.9.11)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: greenlet>=1 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\steph\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# PostgreSQL connection details
PG_USER = "root"
PG_PASSWORD = "root"
PG_HOST = "localhost"  # This is the container name
PG_PORT = 5433
PG_DB = "ny_taxi"

# %%
from sqlalchemy import create_engine

engine = create_engine(
    f'postgresql://{PG_USER}:{PG_PASSWORD}@{PG_HOST}:{PG_PORT}/{PG_DB}'
)
print("✅ Engine created. Ready to test connection...")
# Out:
# ✅ Engine created. Ready to test connection...
